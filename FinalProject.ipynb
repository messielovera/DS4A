# %% [markdown]
# # Importing my data about Humanitarian Demining

# %% [markdown]
# **Business Problem.** In the development of Colombian strategic objectives, and within the framework of the fulfillment of the commitments acquired in the Convention for the Prohibition of Employment, Storage, Production and Transfer of Antipersonnel Mines and on their Destruction ( Ottawa Treaty), the Directorate for Action against Antipersonnel Mines designed a strategic plan focused on overcoming the main obstacles that the implementation of public policy has had, aimed at the consolidation of an efficient and effective institutionality and action sector against Mines, in accordance with the current challenges of the country and by virtue of the functions established in Decree 1649 of 2014. The implementation of the plan has been scheduled from 2016 with goals set to 2021, in accordance with the deadline granted by the Convention for the Prohibition of Antipersonnel Mines to comply with the commitments acquired by the Colombian State.

# %%
# Load packages
import os
import pandas as pd
import numpy as np

# Solve troubles with acents
import unicodedata

# This line is needed to display plots inline in Jupyter Notebook
# %matplotlib inline

# Required for basic python plotting functionality
import matplotlib.pyplot as plt

# Required for formatting dates later in the case
import datetime
import matplotlib.dates as mdates

# Required to display image inline
from IPython.display import Image

# Advanced plotting functionality with seaborn
import seaborn as sns
sns.set(style="whitegrid") # can set style depending on how you'd like it to look

# %%
erm = pd.read_csv('1908base_erm.csv', encoding='utf-8', sep=';')
human_demin = pd.read_csv('1909-Base_Desminado_Humanitario.csv', encoding='utf-8', sep=';')
mine_events = pd.read_csv('1909-Base-Eventos-por-minas.csv', encoding='utf-8', sep=';')
mine_victim = pd.read_csv('1909-Base-Victimas-por-minas.csv', encoding='utf-8', sep=';')
interv_status = pd.read_csv('1909-Estado-Intervencion-Municipios.csv', encoding='utf-8', sep=';')

print ('Showing de data of file 1909-Base_Desminado_Humanitario.csv')
print (erm.info())
print ('Showing de data of file 1909-Base-Eventos-por-minas.csv')
print (human_demin.info())
print ('Showing de data of file 1909-Base-Victimas-por-minas.csv')
print (mine_events.info())
print ('Showing de data of file 1909-Base-Victimas-por-minas.csv')
print (mine_victim.info())
print ('Showing de data of file 1909-Estado-Intervencion-Municipios.csv')
print (interv_status.info())
# Out:
# Showing de data of file 1909-Base_Desminado_Humanitario.csv
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7290 entries, 0 to 7289
# Data columns (total 60 columns):
# id_erm                        7290 non-null object
# mre_guid                      7290 non-null object
# departamento                  7290 non-null object
# municipio                     7290 non-null object
# tipologia                     7264 non-null object
# cod_dane_muni                 7290 non-null int64
# cod_dane_depto                7290 non-null int64
# organización                  7290 non-null object
# motivo_de_actividad           2341 non-null object
# fecha_de_inicio               7290 non-null object
# año_inicio                    7290 non-null int64
# mes                           7290 non-null int64
# fecha_de_finalizacion         4836 non-null object
# nombre_del_sitio              2434 non-null object
# location_guid                 7290 non-null object
# ...
